# %%
pip install openai

# %%
pip install config

# %%
import openai
import config

# %%
openai.api_key ="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"

# %%
from openai import OpenAI
client=OpenAI(api_key=openai.api_key)

# %%
response = client.images.generate(
    model="dall-e-2",
    prompt="An apple floating in water",
    n=1,
    size="1024x1024",
)
image_url=response.data[0].url
print(f"Your image is ready at: {image_url}")
# Out:
# Your image is ready at: https://oaidalleapiprodscus.blob.core.windows.net/private/org-gneqCgnge0fketE8G8T8waaD/user-kpZia2cDskq74mTZtFF01QqJ/img-CGGf6WNFm6l35uBcQ5KWiTMf.png?st=2026-04-06T08%3A12%3A37Z&se=2026-04-06T10%3A12%3A37Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=ae240de5-197c-4e03-af8e-c66aed9a4539&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-04-06T01%3A26%3A05Z&ske=2026-04-07T01%3A26%3A05Z&sks=b&skv=2026-02-06&sig=0qntlZoFWhRpuI5az4dLZUA%2B27OZpYWXSOIzermZryg%3D

# %%
from google.colab import drive

# %%
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive
