# %%
pip install datasets transformers[sentencepiece]

# %%
from transformers import pipeline

# %%
classifier=pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
classifier("Food was amazing ambience was extravagant")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998719692230225}]

# %%
classifier("Food was bad ambience was extremely gloomy")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9993614554405212}]

# %%
classifier("that person is moody")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9914092421531677}]

# %%
classifier(["food was good and ambience was also good","food was bad,ambience was gloomy"])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998706579208374},
#  {'label': 'NEGATIVE', 'score': 0.9991663694381714}]

# %%
zero_shot=pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]

# %%
zero_shot("""The film industry or motion
picture industry comprises the technological and commercial institutions of film-making, i.e., file production companies,file studios,cinematography,animation,
film production, screenwriting, pre-production, post-production,
film festivals, distribution, and actors. Though the expense involved in
making film almost immediately led film production to concentrate under
the auspices of standing production companies, advances in affordable
filmmaking equipment,as well as an expansion of opportunities to acquire investment capital from outside the film industry itself, have allowed independent film
production to evolve.

In 2019, the global box office was worth $42.2 billion. [1]When including box office and home entertainment revenue, the global film industry was worth $136 billion in
2018. [2]Hollywood is the world's oldest national film industry.
and largest in terms of box-office gross revenue """,
          candidate_labels=['education','business','technology','science','food','cinema'])
# Out:
# {'sequence': "The film industry or motion\npicture industry comprises the technological and commercial institutions of film-making, i.e., file production companies,file studios,cinematography,animation,\nfilm production, screenwriting, pre-production, post-production,\nfilm festivals, distribution, and actors. Though the expense involved in\nmaking film almost immediately led film production to concentrate under\nthe auspices of standing production companies, advances in affordable\nfilmmaking equipment,as well as an expansion of opportunities to acquire investment capital from outside the film industry itself, have allowed independent film\nproduction to evolve.\n\nIn 2019, the global box office was worth $42.2 billion. [1]When including box office and home entertainment revenue, the global film industry was worth $136 billion in\n2018. [2]Hollywood is the world's oldest national film industry.\nand largest in terms of box-office gross revenue ",
#  'labels': ['cinema',
# ...

# %%
generator=pipeline('text-generation')
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
generator('In this course we are going to learn about')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
ner=pipeline('ner')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.weight | UNEXPECTED |  |
# bert.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
ner("Iran and US are involved with each other")
# Out:
# [{'entity': 'I-LOC',
#   'score': np.float32(0.99979335),
#   'index': 1,
#   'word': 'Iran',
#   'start': 0,
#   'end': 4},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.9996847),
#   'index': 3,
#   'word': 'US',
#   'start': 9,
#   'end': 11}]

# %%
pipe=pipeline("question-answering",model="ahotrod/electra_large_discriminator_squad2_512")
# Out:
# config.json:   0%|          | 0.00/475 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
import os
os.environ['HF_TOKEN']='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'
